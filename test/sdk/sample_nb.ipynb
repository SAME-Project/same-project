# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import same

# %%
# !pip list --format=freeze
# Out:
# appdirs==1.4.4
# argon2-cffi==20.1.0
# async-generator==1.10
# attrs==21.2.0
# backcall==0.2.0
# backports.entry-points-selectable==1.1.0
# black==21.6b0
# bleach==3.3.0
# certifi==2021.5.30
# cffi==1.14.6
# charset-normalizer==2.0.1
# click==8.0.1
# colorama==0.4.4
# contextlib2==21.6.0
# cryptography==3.4.7
# debugpy==1.3.0
# decorator==5.0.9
# defusedxml==0.7.1
# distlib==0.3.2
# docutils==0.17.1
# e==1.4.5
# entrypoints==0.3
# execnet==1.9.0
# filelock==3.0.12
# flake8==3.9.2
# idna==3.2
# importlib-metadata==4.6.1
# iniconfig==1.1.1
# ipykernel==6.0.2
# ipython==7.25.0
# ipython-genutils==0.2.0
# ipywidgets==7.6.3
# jedi==0.18.0
# jeepney==0.7.0
# Jinja2==3.0.1
# jsonschema==3.2.0
# jupyter==1.0.0
# jupyter-client==6.2.0
# jupyter-console==6.4.0
# jupyter-core==4.7.1
# jupyterlab-pygments==0.1.2
# jupyterlab-widgets==1.0.0
# keyring==23.0.1
# MarkupSafe==2.0.1
# matplotlib-inline==0.1.2
# mccabe==0.6.1
# minimal==0.1.0
# mistune==0.8.4
# mock==4.0.3
# mypy-extensions==0.4.3
# nbclient==0.5.3
# nbconvert==6.1.0
# nbformat==5.1.3
# nest-asyncio==1.5.1
# notebook==6.4.0
# numpy==1.21.0
# opencv-python==4.5.3.56
# packaging==21.0
# pandocfilters==1.4.3
# parso==0.8.2
# path==16.0.0
# path.py==12.5.0
# pathspec==0.8.1
# pexpect==4.8.0
# pickleshare==0.7.5
# pip==21.1.3
# pkginfo==1.7.1
# platformdirs==2.0.2
# pluggy==0.13.1
# prometheus-client==0.11.0
# prompt-toolkit==3.0.19
# ptyprocess==0.7.0
# py==1.10.0
# pycodestyle==2.7.0
# pycparser==2.20
# pyflakes==2.3.1
# Pygments==2.9.0
# pyparsing==2.4.7
# pyrsistent==0.18.0
# pytest==6.2.4
# pytest-fixture-config==1.7.0
# pytest-shutil==1.7.0
# pytest-virtualenv==1.7.0
# python-dateutil==2.8.2
# pyzmq==22.1.0
# q==2.6
# qtconsole==5.1.1
# QtPy==1.9.0
# R==0.0.27
# readme-renderer==29.0
# regex==2021.7.6
# requests==2.26.0
# requests-toolbelt==0.9.1
# rfc3986==1.5.0
# SecretStorage==3.3.1
# Send2Trash==1.7.1
# setuptools==57.1.0
# six==1.16.0
# termcolor==1.1.0
# terminado==0.10.1
# testpath==0.5.0
# toml==0.10.2
# tornado==6.1
# tqdm==4.61.2
# traitlets==5.0.5
# twine==3.4.1
# urllib3==1.26.6
# virtualenv==20.6.0
# wcwidth==0.2.5
# webencodings==0.5.1
# wheel==0.36.2
# widgetsnbextension==3.5.1
# zipp==3.5.0
# WARNING: You are using pip version 21.1.3; however, version 21.2.2 is available.
# You should consider upgrading via the '/home/daaronch/code/same-sdk/.venv/bin/python -m pip install --upgrade pip' command.

# %%
same.import_packages(["minimal"])
# Out:
# Packages installed: minimal

# %%
# !pip list --format=freeze
# Out:
# appdirs==1.4.4
# argon2-cffi==20.1.0
# async-generator==1.10
# attrs==21.2.0
# backcall==0.2.0
# backports.entry-points-selectable==1.1.0
# black==21.6b0
# bleach==3.3.0
# certifi==2021.5.30
# cffi==1.14.6
# charset-normalizer==2.0.1
# click==8.0.1
# colorama==0.4.4
# contextlib2==21.6.0
# cryptography==3.4.7
# debugpy==1.3.0
# decorator==5.0.9
# defusedxml==0.7.1
# distlib==0.3.2
# docutils==0.17.1
# e==1.4.5
# entrypoints==0.3
# execnet==1.9.0
# filelock==3.0.12
# flake8==3.9.2
# idna==3.2
# importlib-metadata==4.6.1
# iniconfig==1.1.1
# ipykernel==6.0.2
# ipython==7.25.0
# ipython-genutils==0.2.0
# ipywidgets==7.6.3
# jedi==0.18.0
# jeepney==0.7.0
# Jinja2==3.0.1
# jsonschema==3.2.0
# jupyter==1.0.0
# jupyter-client==6.2.0
# jupyter-console==6.4.0
# jupyter-core==4.7.1
# jupyterlab-pygments==0.1.2
# jupyterlab-widgets==1.0.0
# keyring==23.0.1
# MarkupSafe==2.0.1
# matplotlib-inline==0.1.2
# mccabe==0.6.1
# minimal==0.1.0
# mistune==0.8.4
# mock==4.0.3
# mypy-extensions==0.4.3
# nbclient==0.5.3
# nbconvert==6.1.0
# nbformat==5.1.3
# nest-asyncio==1.5.1
# notebook==6.4.0
# numpy==1.21.0
# opencv-python==4.5.3.56
# packaging==21.0
# pandocfilters==1.4.3
# parso==0.8.2
# path==16.0.0
# path.py==12.5.0
# pathspec==0.8.1
# pexpect==4.8.0
# pickleshare==0.7.5
# pip==21.1.3
# pkginfo==1.7.1
# platformdirs==2.0.2
# pluggy==0.13.1
# prometheus-client==0.11.0
# prompt-toolkit==3.0.19
# ptyprocess==0.7.0
# py==1.10.0
# pycodestyle==2.7.0
# pycparser==2.20
# pyflakes==2.3.1
# Pygments==2.9.0
# pyparsing==2.4.7
# pyrsistent==0.18.0
# pytest==6.2.4
# pytest-fixture-config==1.7.0
# pytest-shutil==1.7.0
# pytest-virtualenv==1.7.0
# python-dateutil==2.8.2
# pyzmq==22.1.0
# q==2.6
# qtconsole==5.1.1
# QtPy==1.9.0
# R==0.0.27
# readme-renderer==29.0
# regex==2021.7.6
# requests==2.26.0
# requests-toolbelt==0.9.1
# rfc3986==1.5.0
# SecretStorage==3.3.1
# Send2Trash==1.7.1
# setuptools==57.1.0
# six==1.16.0
# termcolor==1.1.0
# terminado==0.10.1
# testpath==0.5.0
# toml==0.10.2
# tornado==6.1
# tqdm==4.61.2
# traitlets==5.0.5
# twine==3.4.1
# urllib3==1.26.6
# virtualenv==20.6.0
# wcwidth==0.2.5
# webencodings==0.5.1
# wheel==0.36.2
# widgetsnbextension==3.5.1
# zipp==3.5.0
# WARNING: You are using pip version 21.1.3; however, version 21.2.2 is available.
# You should consider upgrading via the '/home/daaronch/code/same-sdk/.venv/bin/python -m pip install --upgrade pip' command.

# %%
same.import_packages(["minimal", "regex"])
# Out:
# Packages installed: regex

# %%
# !pip install minimal
# Out:
# Requirement already satisfied: minimal in /home/daaronch/code/same-sdk/.venv/lib/python3.8/site-packages (0.1.0)
# Requirement already satisfied: pytest in /home/daaronch/code/same-sdk/.venv/lib/python3.8/site-packages (from minimal) (6.2.4)
# Requirement already satisfied: iniconfig in /home/daaronch/code/same-sdk/.venv/lib/python3.8/site-packages (from pytest->minimal) (1.1.1)
# Requirement already satisfied: py>=1.8.2 in /home/daaronch/code/same-sdk/.venv/lib/python3.8/site-packages (from pytest->minimal) (1.10.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/daaronch/code/same-sdk/.venv/lib/python3.8/site-packages (from pytest->minimal) (21.2.0)
# Requirement already satisfied: toml in /home/daaronch/code/same-sdk/.venv/lib/python3.8/site-packages (from pytest->minimal) (0.10.2)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /home/daaronch/code/same-sdk/.venv/lib/python3.8/site-packages (from pytest->minimal) (0.13.1)
# Requirement already satisfied: packaging in /home/daaronch/code/same-sdk/.venv/lib/python3.8/site-packages (from pytest->minimal) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/daaronch/code/same-sdk/.venv/lib/python3.8/site-packages (from packaging->pytest->minimal) (2.4.7)
# WARNING: You are using pip version 21.1.3; however, version 21.2.2 is available.
# You should consider upgrading via the '/home/daaronch/code/same-sdk/.venv/bin/python -m pip install --upgrade pip' command.
